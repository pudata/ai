# %% [markdown]
# # Pandas数据分析示例：分析某股票最新数据
#
# ### 面授班讲义  by 杨庆跃
# 请安装最新版本Jupyter notebook进行编程实验

# %% [markdown]
# ## 1、读取数据
# 乐视网的最新交易数据
# 数据源来自雅虎财经，https://finance.yahoo.com/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

stock = pd.read_csv('d:/ai/data/300104.SZ.csv',header=0,parse_dates=['Date'],index_col='Date',na_values=0)
stock.tail()
# Out:
#             Open  High   Low  Close  Adj Close       Volume
# Date
# 2018-09-11  4.15  4.15  4.15   4.15       4.15          NaN
# 2018-09-12  4.15  4.15  4.15   4.15       4.15          NaN
# 2018-09-13  3.74  4.15  3.74   3.74       3.74  300784642.0
# 2018-09-14  3.49  4.10  3.37   3.94       3.94  454721006.0
# 2018-09-17  3.61  4.01  3.55   3.55       3.55  373841628.0

# %% [markdown]
# ## 2、数据浏览与预处理
# 浏览数据格式及规模、各字段数据类型
# 是否有缺失值及异常值
# 是否需要做数据汇总
# 是否需要做数据剔除
# 是否需要生成新字段
# 【提示】重要中间结果应保存

# %%
stock.head()
stock.tail()
# Out:
#             Open  High   Low  Close  Adj Close       Volume
# Date
# 2018-09-03  3.12  3.43  3.04   3.43       3.43  229483191.0
# 2018-09-04  3.62  3.77  3.52   3.77       3.77  162662457.0
# 2018-09-05  4.03  4.15  4.03   4.15       4.15   47574692.0
# 2018-09-06  4.15  4.15  4.15   4.15       4.15          NaN
# 2018-09-07  4.15  4.15  4.15   4.15       4.15          NaN

# %%
stock.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     14.009430    14.305088    13.788186    14.049993    14.049993
# std       9.014056     9.203517     8.873893     9.037231     9.037231
# min       1.685410     1.732060     1.663880     1.663880     1.663880
# 25%       6.973295     7.236360     6.776132     7.026702     7.026702
# 50%      12.211350    12.556800    11.872700    12.292050    12.292050
# 75%      20.451676    21.156825    19.715000    20.548300    20.548300
# max      42.400002    44.750000    41.044998    41.244999    41.244999
#
#              Volume
# count  1.026000e+03
# mean   9.250968e+07
# std    7.427192e+07
# min    6.456000e+05
# 25%    4.257217e+07
# 50%    7.354694e+07
# 75%    1.223078e+08
# max    8.783693e+08

# %% [markdown]
# #### 日期不连续，下面把日期补全

# %%
dates = pd.date_range(start='2012-09-10',end='2018-09-10',freq='D')
dates
# Out:
# DatetimeIndex(['2012-09-10', '2012-09-11', '2012-09-12', '2012-09-13',
#                '2012-09-14', '2012-09-15', '2012-09-16', '2012-09-17',
#                '2012-09-18', '2012-09-19',
#                ...
#                '2018-09-01', '2018-09-02', '2018-09-03', '2018-09-04',
#                '2018-09-05', '2018-09-06', '2018-09-07', '2018-09-08',
#                '2018-09-09', '2018-09-10'],
#               dtype='datetime64[ns]', length=2192, freq='D')

# %%
stock=stock.reindex(dates)
stock.head(20)
# Out:
#                Open     High      Low    Close  Adj Close       Volume
# 2012-09-10  2.79067  2.82177  2.76316  2.77751    2.77751   38645011.0
# 2012-09-11  2.79904  2.82057  2.77392  2.81100    2.81100   58981496.0
# 2012-09-29  2.33134  2.35167  2.30024  2.33014    2.33014          0.0

# %% [markdown]
# 其余缺失值向下填充

# %%
stock.fillna(method='ffill', inplace=True)
stock.head(20)
# Out:
#                Open     High      Low    Close  Adj Close       Volume
# 2012-09-10  2.79067  2.82177  2.76316  2.77751    2.77751   38645011.0
# 2012-09-11  2.79904  2.82057  2.77392  2.81100    2.81100   58981496.0
# 2012-09-12  2.82177  2.83373  2.70933  2.77632    2.77632   50277549.0
# 2012-09-13  2.77512  2.77512  2.71172  2.71292    2.71292   29672156.0
# 2012-09-14  2.71770  2.75000  2.62081  2.71292    2.71292   34779807.0
# 2012-09-15  2.71770  2.75000  2.62081  2.71292    2.71292          0.0
# 2012-09-16  2.71770  2.75000  2.62081  2.71292    2.71292          0.0
# 2012-09-17  2.71292  2.71292  2.71292  2.71292    2.71292          0.0
# 2012-09-18  2.71292  2.71292  2.71292  2.71292    2.71292          0.0
# 2012-09-19  2.71292  2.71292  2.71292  2.71292    2.71292          0.0
# 2012-09-20  2.81100  2.85766  2.70694  2.72727    2.72727  113627463.0
# 2012-09-21  2.69139  2.69139  2.46651  2.53110    2.53110   58780815.0
# 2012-09-22  2.69139  2.69139  2.46651  2.53110    2.53110          0.0
# 2012-09-23  2.69139  2.69139  2.46651  2.53110    2.53110          0.0
# 2012-09-24  2.47608  2.55502  2.44019  2.48206    2.48206   34321829.0
# 2012-09-25  2.46770  2.52751  2.33493  2.37201    2.37201   43041117.0
# 2012-09-26  2.35766  2.38158  2.24880  2.26316    2.26316   39294691.0
# 2012-09-27  2.26316  2.38517  2.26316  2.32656    2.32656   43703839.0
# 2012-09-28  2.33134  2.35167  2.30024  2.33014    2.33014   39152864.0
# 2012-09-29  2.33134  2.35167  2.30024  2.33014    2.33014          0.0

# %%
stock.sort_values('Open',ascending=False).head()
# Out:
#                  Open       High        Low      Close  Adj Close       Volume
# 2015-05-13  42.400002  44.750000  41.044998  41.244999  41.244999  268976944.0
# 2015-05-14  39.500000  40.500000  37.119999  37.119999  37.119999  252358066.0
# 2015-06-05  39.494999  40.810001  37.830002  38.345001  38.345001  147396910.0
# 2015-05-19  39.000000  39.355000  36.090000  36.849998  36.849998  158173398.0
# 2015-06-04  38.744999  40.689999  35.974998  38.290001  38.290001  144958564.0

# %% [markdown]
# 下面对stock数据按月份汇总

# %%
key=lambda x:(x.year,x.month)
#stock_m = stock.groupby(key).mean()
stock_m = stock.groupby(key).agg({
    'Open':'mean',
    'High':'max',
    'Low':'min',
    'Volume':'sum',    
    })
stock_m.head()
stock_m['radio_m']=(stock_m['High']-stock_m['Low'])/stock_m['Low']
stock_m.head()
stock_m.sort_values('radio_m',ascending=False)
stock_m.radio_m.plot.line()

# %% [markdown]
# 画趋势图

# %%
stock_m[['Open','Close']].plot.line()
stock_m.iloc[:,:-1].plot.box()

# %% [markdown]
# 收盘价曲线

# %%
open = stock['Open']

# %%
open.plot.line()
